# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_excel("insurance_claims_raw.xlsx")

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#      months_as_customer   age  policy_number policy_bind_date policy_state  \
# 0                   328  48.0         521585       2014-10-17           OH
# 1                   228  42.0         342868       2006-06-27           IN
# 2                   134  29.0         687698       2000-09-06           OH
# 3                   256  41.0         227811       1990-05-25           IL
# 4                   228  44.0         367455       2014-06-06           IL
# ..                  ...   ...            ...              ...          ...
# 995                   3  38.0         941851       1991-07-16           OH
# 996                 285  41.0         186934       2014-01-05           IL
# 997                 130  34.0         918516       2003-02-17           OH
# 998                 458  62.0         533940       2011-11-18           IL
# 999                 456  60.0         556080       1996-11-11           OH
#
# ...

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               2
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 2
# policy_annual_premium             3
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           1
# insured_occupation                0
# insured_hobbies                   2
# insured_relationship              0
# capital-gains                     2
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            93
# incident_state                    2
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
new_data=df.drop("_c39",axis=1)

# %%
new_data
# Out:
#      months_as_customer   age  policy_number policy_bind_date policy_state  \
# 0                   328  48.0         521585       2014-10-17           OH
# 1                   228  42.0         342868       2006-06-27           IN
# 2                   134  29.0         687698       2000-09-06           OH
# 3                   256  41.0         227811       1990-05-25           IL
# 4                   228  44.0         367455       2014-06-06           IL
# ..                  ...   ...            ...              ...          ...
# 995                   3  38.0         941851       1991-07-16           OH
# 996                 285  41.0         186934       2014-01-05           IL
# 997                 130  34.0         918516       2003-02-17           OH
# 998                 458  62.0         533940       2011-11-18           IL
# 999                 456  60.0         556080       1996-11-11           OH
#
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
fraud_counts = new_data['fraud_reported'].value_counts()

# Plotting with matplotlib
fraud_counts.plot(kind='bar', figsize=(8, 6), color=['green', 'red'])
plt.title('Fraud Reported')
plt.xlabel('Fraud Reported')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
def age_groupes(age):
    if age>=20 and age<30:
        return "young Adults"
    elif age<=30 and age<40:
        return "Adults"
    else:
        return "middle age adult"

# %%
new_data["new_age"]=new_data["age"].apply(age_groupes)

# %%
# Group by 'new_age' and 'fraud_reported' and get the counts
grouped_df2 = new_data.groupby(['new_age', 'fraud_reported']).size().reset_index(name='counts')

# Pivot the data for better visualization
pivot_df2 = grouped_df2.pivot(index='new_age', columns='fraud_reported', values='counts').fillna(0)

# Plotting pie charts for each age range
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))
axes = axes.flatten()

for i, (age, data) in enumerate(pivot_df2.iterrows()):
    data.plot(kind='pie', ax=axes[i], autopct='%1.1f%%', startangle=90, wedgeprops=dict(width=0.3))
    axes[i].set_title(f'Age Range: {age}')
    axes[i].set_ylabel('')

# Hide unused subplots
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.suptitle('Fraud Reported by Age Range')
plt.tight_layout()
plt.show()

# %%
grouped_df = new_data.groupby(['insured_sex', 'fraud_reported']).size().reset_index(name='counts')

# Pivot the data for better visualization
pivot_df = grouped_df.pivot_table(index=['insured_sex'], columns='fraud_reported', values='counts', fill_value=0)

# Plotting
pivot_df.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Fraud Reported by Gender')
plt.xlabel('incident_type')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Fraud Reported')
plt.show()

# %%
grouped_df = new_data.groupby(['incident_type', 'fraud_reported']).size().reset_index(name='counts')

# Pivot the data for better visualization
pivot_df = grouped_df.pivot(index='incident_type', columns='fraud_reported', values='counts').fillna(0)

# Plotting
pivot_df.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Incident Type and Fraud Reported')
plt.xlabel('Incident Type')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Fraud Reported')
plt.show()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# let us look out for missing values

# %%
new_data.head(5)
# Out:
#    months_as_customer   age  policy_number policy_bind_date policy_state  \
# 0                 328  48.0         521585       2014-10-17           OH
# 1                 228  42.0         342868       2006-06-27           IN
# 2                 134  29.0         687698       2000-09-06           OH
# 3                 256  41.0         227811       1990-05-25           IL
# 4                 228  44.0         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500             1000.0                1406.91               0
# 1    250/500             2000.0                1197.22         5000000
# 2    100/300             2000.0                1413.14         5000000
# 3    250/500             2000.0                1415.74         6000000
# 4   500/1000             1000.0                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# ...

# %%
new_data.isnull().sum()
# Out:
# months_as_customer              0
# age                             2
# policy_number                   0
# policy_bind_date                0
# policy_state                    0
# policy_csl                      0
# policy_deductable               2
# policy_annual_premium           3
# umbrella_limit                  0
# insured_zip                     0
# insured_sex                     0
# insured_education_level         1
# insured_occupation              0
# insured_hobbies                 2
# insured_relationship            0
# capital-gains                   2
# capital-loss                    0
# incident_date                   0
# incident_type                   0
# collision_type                  0
# incident_severity               0
# authorities_contacted          93
# incident_state                  2
# incident_city                   0
# incident_location               0
# incident_hour_of_the_day        0
# number_of_vehicles_involved     0
# ...

# %%
new_data.drop("new_age",axis=1,inplace=True)

# %%
new_data.head(5)
# Out:
#    months_as_customer   age  policy_number policy_bind_date policy_state  \
# 0                 328  48.0         521585       2014-10-17           OH
# 1                 228  42.0         342868       2006-06-27           IN
# 2                 134  29.0         687698       2000-09-06           OH
# 3                 256  41.0         227811       1990-05-25           IL
# 4                 228  44.0         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500             1000.0                1406.91               0
# 1    250/500             2000.0                1197.22         5000000
# 2    100/300             2000.0                1413.14         5000000
# 3    250/500             2000.0                1415.74         6000000
# 4   500/1000             1000.0                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# ...

# %% [markdown]
# The below code is used to fill Null Values by imputing them with mean value for columns containing integers and impute with mode for columns containing string values

# %%
new_data.isnull().sum()
# Out:
# months_as_customer              0
# age                             2
# policy_number                   0
# policy_bind_date                0
# policy_state                    0
# policy_csl                      0
# policy_deductable               2
# policy_annual_premium           3
# umbrella_limit                  0
# insured_zip                     0
# insured_sex                     0
# insured_education_level         1
# insured_occupation              0
# insured_hobbies                 2
# insured_relationship            0
# capital-gains                   2
# capital-loss                    0
# incident_date                   0
# incident_type                   0
# collision_type                  0
# incident_severity               0
# authorities_contacted          93
# incident_state                  2
# incident_city                   0
# incident_location               0
# incident_hour_of_the_day        0
# number_of_vehicles_involved     0
# ...

# %%
new_data['collision_type'].replace('?', pd.NA, inplace=True)
new_data['police_report_available'].replace('?', pd.NA, inplace=True)
new_data['property_damage'].replace('?', pd.NA, inplace=True)
# Out:
# C:\Users\Lindelani\AppData\Local\Temp\ipykernel_67160\542088527.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   new_data['collision_type'].replace('?', pd.NA, inplace=True)
# C:\Users\Lindelani\AppData\Local\Temp\ipykernel_67160\542088527.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
new_data["age"]=df["age"].fillna(df["age"].mean())   # imputing the null values for age with their mean

new_data["policy_annual_premium"]=new_data["policy_annual_premium"].fillna(new_data["policy_annual_premium"].mean()) #imputing the null values for policy_annual_premium with their mean 
new_data["policy_deductable"]=new_data["policy_deductable"].fillna(new_data["policy_deductable"].mean())
new_data["authorities_contacted"]=new_data["authorities_contacted"].fillna(new_data["authorities_contacted"].mode()[0])
new_data["incident_state"]=new_data["incident_state"].fillna(new_data["incident_state"].mode()[0])                                                               
new_data["insured_hobbies"]=new_data["insured_hobbies"].fillna(new_data["insured_hobbies"].mode()[0])
new_data["capital-gains"]=new_data["capital-gains"].fillna(new_data["capital-gains"].mode()[0])
new_data["insured_education_level"]=new_data["insured_education_level"].fillna(new_data["insured_education_level"].mode()[0])
new_data["property_damage"]=new_data["property_damage"].fillna(new_data["property_damage"].mode()[0])
new_data["police_report_available"]=new_data["police_report_available"].fillna(new_data["police_report_available"].mode()[0])
new_data["collision_type"]=new_data["collision_type"].fillna(new_data["collision_type"].mode()[0])

# %%
new_data.head(5)
# Out:
#    months_as_customer   age  policy_number policy_bind_date policy_state  \
# 0                 328  48.0         521585       2014-10-17           OH
# 1                 228  42.0         342868       2006-06-27           IN
# 2                 134  29.0         687698       2000-09-06           OH
# 3                 256  41.0         227811       1990-05-25           IL
# 4                 228  44.0         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500             1000.0                1406.91               0
# 1    250/500             2000.0                1197.22         5000000
# 2    100/300             2000.0                1413.14         5000000
# 3    250/500             2000.0                1415.74         6000000
# 4   500/1000             1000.0                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# ...

# %% [markdown]
# In order for Machine Learning Algorthms to build models it need to interact with columns that are numeric. As a result we need to use Sckit-learn Algorthm (LabelEncoder) to create dummies for each an every column that contist of categories which are strings

# %%
label_encoder=LabelEncoder()

# %%
new_data["policy_csl"] = new_data["policy_csl"].map(csl_mapping)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 new_data["policy_csl"] = new_data["policy_csl"].map(csl_mapping)
#
# NameError: name 'csl_mapping' is not defined

# %%
new_data["auto_model"]=new_data["auto_model"].astype(str)

# %%
list=["incident_type","policy_state","insured_relationship","incident_severity","authorities_contacted","insured_sex","insured_education_level","insured_occupation","insured_hobbies","collision_type","incident_state","incident_city","incident_location","property_damage","police_report_available","auto_make","auto_model","fraud_reported"]
def encode_columns(df,list):
    for x in list:
        if x in new_data.columns:
            new_data[x]=label_encoder.fit_transform(new_data[x])
    return new_data
encode_columns(new_data,list)
# Out:
#      months_as_customer   age  policy_number policy_bind_date  policy_state  \
# 0             27.333333  48.0         521585       2014-10-17             2
# 1             19.000000  42.0         342868       2006-06-27             1
# 2             11.166667  29.0         687698       2000-09-06             2
# 3             21.333333  41.0         227811       1990-05-25             0
# 4             19.000000  44.0         367455       2014-06-06             0
# ..                  ...   ...            ...              ...           ...
# 995            0.250000  38.0         941851       1991-07-16             2
# 996           23.750000  41.0         186934       2014-01-05             0
# 997           10.833333  34.0         918516       2003-02-17             2
# 998           38.166667  62.0         533940       2011-11-18             0
# 999           38.000000  60.0         556080       1996-11-11             2
#
# ...

# %%
new_data["insured_sex"]=label_encoder.fit_transform(new_data["insured_sex"])
new_data["fraud_reported"]=label_encoder.fit_transform(new_data["fraud_reported"])
new_data["police_report_available"]=label_encoder.fit_transform(new_data["police_report_available"])
new_data["property_damage"]=label_encoder.fit_transform(new_data["property_damage"])
new_data["incident_severity"]=label_encoder.fit_transform(new_data["incident_severity"])
new_data["collision_type"]=label_encoder.fit_transform(new_data["collision_type"])

# %%
new_data
# Out:
#      months_as_customer   age  policy_number policy_bind_date  policy_state  \
# 0             27.333333  48.0         521585       2014-10-17             2
# 1             19.000000  42.0         342868       2006-06-27             1
# 2             11.166667  29.0         687698       2000-09-06             2
# 3             21.333333  41.0         227811       1990-05-25             0
# 4             19.000000  44.0         367455       2014-06-06             0
# ..                  ...   ...            ...              ...           ...
# 995            0.250000  38.0         941851       1991-07-16             2
# 996           23.750000  41.0         186934       2014-01-05             0
# 997           10.833333  34.0         918516       2003-02-17             2
# 998           38.166667  62.0         533940       2011-11-18             0
# 999           38.000000  60.0         556080       1996-11-11             2
#
# ...

# %%
new_data["months_as_customer"]=new_data["months_as_customer"]/12

# %%
new_data
# Out:
#      months_as_customer   age  policy_number policy_bind_date  policy_state  \
# 0             27.333333  48.0         521585       2014-10-17             2
# 1             19.000000  42.0         342868       2006-06-27             1
# 2             11.166667  29.0         687698       2000-09-06             2
# 3             21.333333  41.0         227811       1990-05-25             0
# 4             19.000000  44.0         367455       2014-06-06             0
# ..                  ...   ...            ...              ...           ...
# 995            0.250000  38.0         941851       1991-07-16             2
# 996           23.750000  41.0         186934       2014-01-05             0
# 997           10.833333  34.0         918516       2003-02-17             2
# 998           38.166667  62.0         533940       2011-11-18             0
# 999           38.000000  60.0         556080       1996-11-11             2
#
# ...

# %%
x=new_data.drop(["fraud_reported","incident_date","policy_bind_date","policy_number"],axis=1)

# %%
x.values
# Out:
# array([[2.2777777777777777, 48.0, 2, ..., 10, 1, 2004],
#        [1.5833333333333333, 42.0, 1, ..., 8, 33, 2007],
#        [0.9305555555555555, 29.0, 2, ..., 4, 17, 2007],
#        ...,
#        [0.9027777777777778, 34.0, 2, ..., 11, 3, 1996],
#        [3.1805555555555554, 62.0, 0, ..., 1, 28, 1998],
#        [3.1666666666666665, 60.0, 2, ..., 8, 33, 2007]], dtype=object)

# %%
y=new_data["fraud_reported"]

# %%
y
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: fraud_reported, Length: 1000, dtype: int64

# %% [markdown]
# # Modelling

# %% [markdown]
# ## Logistic Regression

# %%
LR=LogisticRegression()

# %%
LR.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 LR.fit(x,y)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py:1201, in LogisticRegression.fit(self, X, y, sample_weight)
#    1198 else:
#    1199     _dtype = [np.float64, np.float32]
# -> 1201 X, y = self._validate_data(
#    1202     X,
#    1203     y,
#    1204     accept_sparse="csr",
#    1205     dtype=_dtype,
# ...
